# %%
import pandas as pd

# %%
df = pd.read_csv("RefugeeMigrant_Deaths.csv")

df_routes = df[~(df.route=="Unknown")]
df_routes = df_routes.drop(['quarter', 'location'],axis=1)
df_routes = df_routes.dropna(how='any')
df_routes = df_routes.astype({"Year": int, 'dead_and_missing': int})

# %%
df_routes.isnull().sum()
# Out:
# route                     0
# Location                  0
# CartoDB_Cause_of_death    0
# cause_of_death            0
# Year                      0
# dead_and_missing          0
# dtype: int64

# %% [markdown]
# #### Prepare CSV format

# %%
filteredsankey = pd.DataFrame(df_routes[['Location', 'Year', 'dead_and_missing', 'route', 'CartoDB_Cause_of_death', 'cause_of_death']]\
.rename({'Location': 'state', 'Year': 'fiscal_year', 'dead_and_missing': 'value',
                      'route': 'agency', 'CartoDB_Cause_of_death': 'bureau', 'cause_of_death': 'program'}, axis=1)\
.reset_index(drop=True)\
.groupby(['state','fiscal_year','agency','bureau','program'])['value']\
                          .sum()\
                             .reset_index())

# %%
filteredsankey = filteredsankey.rename({'state': 'location', 'fiscal_year': 'event_year', 'agency': 'route', 
                       'bureau': 'causal', 'program': 'reason'}, axis=1)

# %%
filteredsankey.to_csv("filteredsankey.csv")

# %% [markdown]
# #### Prepare JSON format

# %%
# prepare nodes dictionary
df_nodes = df_routes.copy()
df_nodes = df_nodes.astype({"Year": str})
df_nodes = pd.DataFrame(df_nodes[['route','Location', 'Year', 'CartoDB_Cause_of_death']]\
                        .unstack(level=1).reset_index(drop=True).unique())
df_nodes.columns = ['name']
dict_nodes = df_nodes.to_dict('records')

# %%
# prepare links dictionary
dict_yearRoute = df_routes.groupby(['Year','route'])['dead_and_missing']\
                          .sum()\
                          .reset_index()\
                          .sort_values(by=['Year'], ascending=False)\
                          .astype({"Year": str})\
                          .rename({'Year': 'source', 'route': 'target', 'dead_and_missing': 'value'}, axis=1)\
                          .to_dict('records')

dict_routeLocation = df_routes.groupby(['route', 'Location'])['dead_and_missing']\
                              .sum()\
                              .reset_index()\
                              .sort_values(by=['route', 'Location', 'dead_and_missing'], ascending=True)\
                              .rename({'route': 'source', 'Location': 'target', 'dead_and_missing': 'value'}, axis=1)\
                              .to_dict('records')

dict_locationCausalities = df_routes.groupby(['Location', 'CartoDB_Cause_of_death'])['dead_and_missing']\
                              .sum()\
                              .reset_index()\
                              .sort_values(by=['Location','CartoDB_Cause_of_death', 'dead_and_missing'], ascending=True)\
                              .rename({'Location': 'source', 'CartoDB_Cause_of_death': 'target', 'dead_and_missing': 'value'}, axis=1)\
                              .to_dict('records')

dict_causalitiesYear = df_routes.groupby(['CartoDB_Cause_of_death', 'Year'])['dead_and_missing']\
                          .sum()\
                          .reset_index()\
                          .sort_values(by=['CartoDB_Cause_of_death'], ascending=False)\
                          .astype({"Year": str})\
                          .rename({'CartoDB_Cause_of_death': 'source', 'Year': 'target', 'dead_and_missing': 'value'}, axis=1)\
                          .to_dict('records')

# collect all the link dictionaries
# dict_links = dict_yearRoute + dict_routeLocation + dict_locationCausalities
dict_links = dict_routeLocation + dict_locationCausalities + dict_causalitiesYear

# %%
data = {'links': dict_links,
        'nodes': dict_nodes}

# %%
import json

with open('data.json', 'w') as fp:
    json.dump(data, fp)

# %%
data
# Out:
# {'links': [{'source': 'Apulia and Calabria Route',
#    'target': 'Albania',
#    'value': 63},
#   {'source': 'Apulia and Calabria Route', 'target': 'Greece', 'value': 13},
#   {'source': 'Apulia and Calabria Route', 'target': 'Italy', 'value': 383},
#   {'source': 'Apulia and Calabria Route',
#    'target': 'Southern Adriatic',
#    'value': 3},
#   {'source': 'Central European Route', 'target': 'Germany', 'value': 2},
#   {'source': 'Central European Route', 'target': 'Hungary', 'value': 2},
#   {'source': 'Central European Route', 'target': 'Lampedusa', 'value': 19},
#   {'source': 'Central European Route', 'target': 'Libya', 'value': 82},
#   {'source': 'Central European Route', 'target': 'Niger', 'value': 18},
#   {'source': 'Central European Route', 'target': 'Sardinia', 'value': 4},
#   {'source': 'Central European Route', 'target': 'Sicily', 'value': 12},
#   {'source': 'Central Mediterranean Route', 'target': 'Africa', 'value': 54},
#   {'source': 'Central Mediterranean Route', 'target': 'Algeria', 'value': 215},
#   {'source': 'Central Mediterranean Route', 'target': 'Catania', 'value': 224},
#   {'source': 'Central Mediterranean Route', 'target': 'Chad', 'value': 1},
#   {'source': 'Central Mediterranean Route', 'target': 'Edko', 'value': 8},
#   {'source': 'Central Mediterranean Route', 'target': 'Egypt', 'value': 140},
#   {'source': 'Central Mediterranean Route', 'target': 'France', 'value': 17},
#   {'source': 'Central Mediterranean Route', 'target': 'Italy', 'value': 199},
#   {'source': 'Central Mediterranean Route',
#    'target': 'Lampedusa',
#    'value': 4212},
#   {'source': 'Central Mediterranean Route', 'target': 'Libya', 'value': 6019},
#   {'source': 'Central Mediterranean Route', 'target': 'Linosa', 'value': 5},
#   {'source': 'Central Mediterranean Route', 'target': 'Malta', 'value': 1267},
#   {'source': 'Central Mediterranean Route',
#    'target': 'Mediterranean Sea',
#    'value': 30},
#   {'source': 'Central Mediterranean Route', 'target': 'Morocco', 'value': 14},
#   {'source': 'Central Mediterranean Route', 'target': 'Niger', 'value': 1},
#   {'source': 'Central Mediterranean Route',
#    'target': 'Pantelleria',
#    'value': 35},
#   {'source': 'Central Mediterranean Route',
#    'target': 'Sardinia',
#    'value': 160},
#   {'source': 'Central Mediterranean Route', 'target': 'Sicily', 'value': 569},
#   {'source': 'Central Mediterranean Route',
#    'target': 'Tunisia',
#    'value': 1051},
#   {'source': 'Central Mediterranean Route', 'target': 'Zelid', 'value': 41},
#   {'source': 'Central Mediterranean route', 'target': 'Catania', 'value': 68},
#   {'source': 'Central Mediterranean route',
#    'target': 'Central Mediterranean',
#    'value': 3},
#   {'source': 'Central Mediterranean route', 'target': 'Egypt', 'value': 10},
#   {'source': 'Central Mediterranean route', 'target': 'Italy', 'value': 36},
#   {'source': 'Central Mediterranean route',
#    'target': 'Lampedusa',
#    'value': 50},
#   {'source': 'Central Mediterranean route', 'target': 'Libya', 'value': 2086},
#   {'source': 'Central Mediterranean route', 'target': 'Malta', 'value': 31},
#   {'source': 'Central Mediterranean route',
#    'target': 'Mediterranean Sea',
#    'value': 2},
#   {'source': 'Central Mediterranean route', 'target': 'Niger', 'value': 48},
#   {'source': 'Central Mediterranean route', 'target': 'Sicily', 'value': 41},
#   {'source': 'Circular Route from Greece and Albania',
#    'target': 'Albania',
#    'value': 3},
#   {'source': 'Circular Route from Greece and Albania',
#    'target': 'Greece',
#    'value': 5},
#   {'source': 'Eastern Borders Route', 'target': 'Greece', 'value': 4},
#   {'source': 'Eastern Borders Route', 'target': 'Hungary', 'value': 16},
#   {'source': 'Eastern Borders Route', 'target': 'Lithuania', 'value': 1},
#   {'source': 'Eastern Borders Route', 'target': 'Slovakia', 'value': 5},
#   {'source': 'Eastern Borders Route', 'target': 'Ukraine', 'value': 1},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Aegean', 'value': 1037},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Bulgaria', 'value': 16},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Crete', 'value': 84},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Cyprus', 'value': 35},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Egypt', 'value': 2},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Greece', 'value': 351},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Libya', 'value': 6},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Spain', 'value': 4},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Syria', 'value': 7},
#   {'source': 'Eastern Mediterranean Route', 'target': 'Turkey', 'value': 836},
#   {'source': 'Western African Route', 'target': 'Africa', 'value': 41},
#   {'source': 'Western African Route', 'target': 'Barbados', 'value': 37},
#   {'source': 'Western African Route', 'target': 'Bojador', 'value': 14},
#   {'source': 'Western African Route',
#    'target': 'Canary Islands',
#    'value': 1015},
#   {'source': 'Western African Route', 'target': 'Dakar', 'value': 173},
#   {'source': 'Western African Route', 'target': 'Gambia', 'value': 58},
#   {'source': 'Western African Route', 'target': 'Guine', 'value': 38},
#   {'source': 'Western African Route',
#    'target': 'Las Palmas, Spain',
#    'value': 811},
#   {'source': 'Western African Route', 'target': 'Mauritania', 'value': 370},
#   {'source': 'Western African Route', 'target': 'Morocco', 'value': 603},
#   {'source': 'Western African Route', 'target': 'Senegal', 'value': 510},
#   {'source': 'Western African Route', 'target': 'Spain', 'value': 53},
#   {'source': 'Western Balkan Route', 'target': 'Austria', 'value': 75},
#   {'source': 'Western Balkan Route', 'target': 'Croatia', 'value': 9},
#   {'source': 'Western Balkan Route', 'target': 'Hungary', 'value': 3},
#   {'source': 'Western Balkan Route', 'target': 'Italy', 'value': 2},
#   {'source': 'Western Balkan Route', 'target': 'Macedonia', 'value': 14},
#   {'source': 'Western Balkan Route', 'target': 'Poland', 'value': 1},
#   {'source': 'Western Balkan Route', 'target': 'Romania', 'value': 3},
#   {'source': 'Western Balkan Route', 'target': 'Serbia', 'value': 1},
#   {'source': 'Western Balkan Route', 'target': 'Slovenia', 'value': 1},
#   {'source': 'Western Mediterranean Route', 'target': 'Africa', 'value': 139},
#   {'source': 'Western Mediterranean Route', 'target': 'Algeria', 'value': 406},
#   {'source': 'Western Mediterranean Route',
#    'target': 'Balearic Islands',
#    'value': 5},
#   {'source': 'Western Mediterranean Route', 'target': 'Cameroon', 'value': 1},
#   {'source': 'Western Mediterranean Route', 'target': 'Egypt', 'value': 11},
#   {'source': 'Western Mediterranean Route', 'target': 'France', 'value': 1},
#   {'source': 'Western Mediterranean Route',
#    'target': 'Gibraltar',
#    'value': 116},
#   {'source': 'Western Mediterranean Route', 'target': 'Libya', 'value': 7},
#   {'source': 'Western Mediterranean Route',
#    'target': 'Mediterranean Sea',
#    'value': 2},
#   {'source': 'Western Mediterranean Route', 'target': 'Morocco', 'value': 917},
#   {'source': 'Western Mediterranean Route', 'target': 'Portugal', 'value': 1},
#   {'source': 'Western Mediterranean Route', 'target': 'Spain', 'value': 1865},
#   {'source': 'Aegean', 'target': 'authorities related death', 'value': 2},
#   {'source': 'Aegean',
#    'target': 'drowning or exhaustion related death',
#    'value': 732},
#   {'source': 'Aegean',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 298},
#   {'source': 'Aegean',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 5},
#   {'source': 'Africa',
#    'target': 'drowning or exhaustion related death',
#    'value': 173},
#   {'source': 'Africa',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 16},
#   {'source': 'Africa', 'target': 'suicide', 'value': 1},
#   {'source': 'Africa',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 44},
#   {'source': 'Albania',
#    'target': 'drowning or exhaustion related death',
#    'value': 50},
#   {'source': 'Albania',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 16},
#   {'source': 'Algeria',
#    'target': 'drowning or exhaustion related death',
#    'value': 457},
#   {'source': 'Algeria',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 2},
#   {'source': 'Algeria',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 162},
#   {'source': 'Austria',
#    'target': 'drowning or exhaustion related death',
#    'value': 71},
#   {'source': 'Austria',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 1},
#   {'source': 'Austria', 'target': 'suicide', 'value': 1},
#   {'source': 'Austria',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 2},
#   {'source': 'Balearic Islands',
#    'target': 'drowning or exhaustion related death',
#    'value': 5},
#   {'source': 'Barbados',
#    'target': 'drowning or exhaustion related death',
#    'value': 37},
#   {'source': 'Bojador',
#    'target': 'drowning or exhaustion related death',
#    'value': 14},
#   {'source': 'Bulgaria', 'target': 'authorities related death', 'value': 2},
#   {'source': 'Bulgaria',
#    'target': 'drowning or exhaustion related death',
#    'value': 14},
#   {'source': 'Cameroon',
#    'target': 'drowning or exhaustion related death',
#    'value': 1},
#   {'source': 'Canary Islands',
#    'target': 'authorities related death',
#    'value': 2},
#   {'source': 'Canary Islands',
#    'target': 'drowning or exhaustion related death',
#    'value': 679},
#   {'source': 'Canary Islands', 'target': 'suicide', 'value': 4},
#   {'source': 'Canary Islands',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 312},
#   {'source': 'Canary Islands',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 18},
#   {'source': 'Catania',
#    'target': 'drowning or exhaustion related death',
#    'value': 151},
#   {'source': 'Catania',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 1},
#   {'source': 'Catania',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 140},
#   {'source': 'Central Mediterranean',
#    'target': 'drowning or exhaustion related death',
#    'value': 3},
#   {'source': 'Chad',
#    'target': 'drowning or exhaustion related death',
#    'value': 1},
#   {'source': 'Crete',
#    'target': 'drowning or exhaustion related death',
#    'value': 72},
#   {'source': 'Crete',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 12},
#   {'source': 'Croatia', 'target': 'authorities related death', 'value': 1},
#   {'source': 'Croatia',
#    'target': 'drowning or exhaustion related death',
#    'value': 8},
#   {'source': 'Cyprus', 'target': 'authorities related death', 'value': 1},
#   {'source': 'Cyprus',
#    'target': 'drowning or exhaustion related death',
#    'value': 34},
#   {'source': 'Dakar',
#    'target': 'drowning or exhaustion related death',
#    'value': 107},
#   {'source': 'Dakar',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 62},
#   {'source': 'Dakar',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 4},
#   {'source': 'Edko',
#    'target': 'drowning or exhaustion related death',
#    'value': 8},
#   {'source': 'Egypt', 'target': 'authorities related death', 'value': 2},
#   {'source': 'Egypt',
#    'target': 'drowning or exhaustion related death',
#    'value': 160},
#   {'source': 'Egypt',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 1},
#   {'source': 'France',
#    'target': 'drowning or exhaustion related death',
#    'value': 17},
#   {'source': 'France',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 1},
#   {'source': 'Gambia',
#    'target': 'drowning or exhaustion related death',
#    'value': 58},
#   {'source': 'Germany',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 2},
#   {'source': 'Gibraltar',
#    'target': 'drowning or exhaustion related death',
#    'value': 62},
#   {'source': 'Gibraltar',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 54},
#   {'source': 'Greece', 'target': 'authorities related death', 'value': 3},
#   {'source': 'Greece',
#    'target': 'drowning or exhaustion related death',
#    'value': 232},
#   {'source': 'Greece', 'target': 'other', 'value': 1},
#   {'source': 'Greece',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 53},
#   {'source': 'Greece',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 84},
#   {'source': 'Guine',
#    'target': 'drowning or exhaustion related death',
#    'value': 38},
#   {'source': 'Hungary',
#    'target': 'drowning or exhaustion related death',
#    'value': 17},
#   {'source': 'Hungary',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 1},
#   {'source': 'Hungary', 'target': 'suicide', 'value': 1},
#   {'source': 'Hungary',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 2},
#   {'source': 'Italy',
#    'target': 'drowning or exhaustion related death',
#    'value': 436},
#   {'source': 'Italy',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 24},
#   {'source': 'Italy', 'target': 'suicide', 'value': 1},
#   {'source': 'Italy',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 152},
#   {'source': 'Italy',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 7},
#   {'source': 'Lampedusa',
#    'target': 'drowning or exhaustion related death',
#    'value': 3665},
#   {'source': 'Lampedusa',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 616},
#   {'source': 'Las Palmas, Spain',
#    'target': 'authorities related death',
#    'value': 1},
#   {'source': 'Las Palmas, Spain',
#    'target': 'drowning or exhaustion related death',
#    'value': 675},
#   {'source': 'Las Palmas, Spain',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 135},
#   {'source': 'Libya', 'target': 'authorities related death', 'value': 2},
#   {'source': 'Libya',
#    'target': 'drowning or exhaustion related death',
#    'value': 6961},
#   {'source': 'Libya',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 21},
#   {'source': 'Libya',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 1215},
#   {'source': 'Libya',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 1},
#   {'source': 'Linosa',
#    'target': 'drowning or exhaustion related death',
#    'value': 2},
#   {'source': 'Linosa',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 3},
#   {'source': 'Lithuania', 'target': 'suicide', 'value': 1},
#   {'source': 'Macedonia',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 14},
#   {'source': 'Malta', 'target': 'authorities related death', 'value': 1},
#   {'source': 'Malta',
#    'target': 'drowning or exhaustion related death',
#    'value': 997},
#   {'source': 'Malta',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 1},
#   {'source': 'Malta', 'target': 'suicide', 'value': 1},
#   {'source': 'Malta',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 288},
#   {'source': 'Malta',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 10},
#   {'source': 'Mauritania',
#    'target': 'drowning or exhaustion related death',
#    'value': 284},
#   {'source': 'Mauritania', 'target': 'suicide', 'value': 10},
#   {'source': 'Mauritania',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 76},
#   {'source': 'Mediterranean Sea',
#    'target': 'drowning or exhaustion related death',
#    'value': 32},
#   {'source': 'Mediterranean Sea',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 2},
#   {'source': 'Morocco', 'target': 'authorities related death', 'value': 2},
#   {'source': 'Morocco',
#    'target': 'drowning or exhaustion related death',
#    'value': 1140},
#   {'source': 'Morocco',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 8},
#   {'source': 'Morocco', 'target': 'suicide', 'value': 1},
#   {'source': 'Morocco',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 381},
#   {'source': 'Morocco',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 2},
#   {'source': 'Niger',
#    'target': 'drowning or exhaustion related death',
#    'value': 37},
#   {'source': 'Niger',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 30},
#   {'source': 'Pantelleria',
#    'target': 'drowning or exhaustion related death',
#    'value': 29},
#   {'source': 'Pantelleria',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 6},
#   {'source': 'Poland',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 1},
#   {'source': 'Portugal',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 1},
#   {'source': 'Romania',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 3},
#   {'source': 'Sardinia',
#    'target': 'drowning or exhaustion related death',
#    'value': 107},
#   {'source': 'Sardinia', 'target': 'suicide', 'value': 1},
#   {'source': 'Sardinia',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 56},
#   {'source': 'Senegal',
#    'target': 'drowning or exhaustion related death',
#    'value': 290},
#   {'source': 'Senegal',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 220},
#   {'source': 'Serbia',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 1},
#   {'source': 'Sicily',
#    'target': 'drowning or exhaustion related death',
#    'value': 372},
#   {'source': 'Sicily',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 4},
#   {'source': 'Sicily',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 246},
#   {'source': 'Slovakia',
#    'target': 'drowning or exhaustion related death',
#    'value': 4},
#   {'source': 'Slovakia',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 1},
#   {'source': 'Slovenia',
#    'target': 'drowning or exhaustion related death',
#    'value': 1},
#   {'source': 'Southern Adriatic',
#    'target': 'drowning or exhaustion related death',
#    'value': 3},
#   {'source': 'Spain', 'target': 'authorities related death', 'value': 47},
#   {'source': 'Spain',
#    'target': 'drowning or exhaustion related death',
#    'value': 1454},
#   {'source': 'Spain',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 6},
#   {'source': 'Spain', 'target': 'other', 'value': 2},
#   {'source': 'Spain', 'target': 'suicide', 'value': 8},
#   {'source': 'Spain',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 352},
#   {'source': 'Spain',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 53},
#   {'source': 'Syria',
#    'target': 'drowning or exhaustion related death',
#    'value': 7},
#   {'source': 'Tunisia',
#    'target': 'drowning or exhaustion related death',
#    'value': 825},
#   {'source': 'Tunisia',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 4},
#   {'source': 'Tunisia',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 221},
#   {'source': 'Tunisia',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 1},
#   {'source': 'Turkey',
#    'target': 'drowning or exhaustion related death',
#    'value': 614},
#   {'source': 'Turkey',
#    'target': 'malicious intent related death / manslaughter',
#    'value': 2},
#   {'source': 'Turkey',
#    'target': 'unknown - supposedly exhaustion related death',
#    'value': 215},
#   {'source': 'Turkey',
#    'target': 'violent accidental death (transport, blown in minefield, etc)',
#    'value': 5},
#   {'source': 'Ukraine',
#    'target': 'drowning or exhaustion related death',
#    'value': 1},
#   {'source': 'Zelid',
#    'target': 'drowning or exhaustion related death',
#    'value': 41},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2015',
#    'value': 24},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2007',
#    'value': 4},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2000',
#    'value': 35},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2001',
#    'value': 24},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2002',
#    'value': 8},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2003',
#    'value': 16},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2005',
#    'value': 15},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2006',
#    'value': 29},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2004',
#    'value': 19},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2008',
#    'value': 13},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2009',
#    'value': 2},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2010',
#    'value': 2},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2011',
#    'value': 5},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2012',
#    'value': 2},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2013',
#    'value': 4},
#   {'source': 'violent accidental death (transport, blown in minefield, etc)',
#    'target': '2014',
#    'value': 12},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2007',
#    'value': 990},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2000',
#    'value': 100},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2001',
#    'value': 90},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2002',
#    'value': 323},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2003',
#    'value': 107},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2004',
#    'value': 312},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2005',
#    'value': 420},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2006',
#    'value': 629},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2011',
#    'value': 176},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2008',
#    'value': 650},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2010',
#    'value': 11},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2012',
#    'value': 115},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2013',
#    'value': 1},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2014',
#    'value': 328},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2015',
#    'value': 986},
#   {'source': 'unknown - supposedly exhaustion related death',
#    'target': '2009',
#    'value': 133},
#   {'source': 'suicide', 'target': '2007', 'value': 11},
#   {'source': 'suicide', 'target': '2004', 'value': 2},
#   {'source': 'suicide', 'target': '2005', 'value': 1},
#   {'source': 'suicide', 'target': '2006', 'value': 5},
#   {'source': 'suicide', 'target': '2011', 'value': 1},
#   {'source': 'suicide', 'target': '2008', 'value': 1},
#   {'source': 'suicide', 'target': '2009', 'value': 2},
#   {'source': 'suicide', 'target': '2010', 'value': 1},
#   {'source': 'suicide', 'target': '2002', 'value': 2},
#   {'source': 'suicide', 'target': '2003', 'value': 2},
#   {'source': 'suicide', 'target': '2001', 'value': 1},
#   {'source': 'suicide', 'target': '2000', 'value': 1},
#   {'source': 'other', 'target': '2010', 'value': 1},
#   {'source': 'other', 'target': '2009', 'value': 2},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2004',
#    'value': 3},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2007',
#    'value': 1},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2000',
#    'value': 5},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2001',
#    'value': 14},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2003',
#    'value': 17},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2005',
#    'value': 10},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2008',
#    'value': 12},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2010',
#    'value': 21},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2011',
#    'value': 5},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2012',
#    'value': 1},
#   {'source': 'malicious intent related death / manslaughter',
#    'target': '2015',
#    'value': 3},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2003',
#    'value': 1526},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2005',
#    'value': 771},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2004',
#    'value': 865},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2009',
#    'value': 1578},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2002',
#    'value': 621},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2001',
#    'value': 322},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2000',
#    'value': 519},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2007',
#    'value': 1456},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2006',
#    'value': 1544},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2012',
#    'value': 703},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2008',
#    'value': 1041},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2010',
#    'value': 223},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2011',
#    'value': 3897},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2013',
#    'value': 719},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2014',
#    'value': 2922},
#   {'source': 'drowning or exhaustion related death',
#    'target': '2015',
#    'value': 2471},
#   {'source': 'authorities related death', 'target': '2008', 'value': 2},
#   {'source': 'authorities related death', 'target': '2003', 'value': 2},
#   {'source': 'authorities related death', 'target': '2004', 'value': 4},
#   {'source': 'authorities related death', 'target': '2005', 'value': 21},
#   {'source': 'authorities related death', 'target': '2006', 'value': 8},
#   {'source': 'authorities related death', 'target': '2007', 'value': 2},
#   {'source': 'authorities related death', 'target': '2002', 'value': 2},
#   {'source': 'authorities related death', 'target': '2009', 'value': 1},
#   {'source': 'authorities related death', 'target': '2011', 'value': 2},
#   {'source': 'authorities related death', 'target': '2013', 'value': 2},
#   {'source': 'authorities related death', 'target': '2014', 'value': 13},
#   {'source': 'authorities related death', 'target': '2015', 'value': 4},
#   {'source': 'authorities related death', 'target': '2000', 'value': 3}],
#  'nodes': [{'name': 'Eastern Mediterranean Route'},
#   {'name': 'Western Mediterranean Route'},
#   {'name': 'Central Mediterranean Route'},
#   {'name': 'Western Balkan Route'},
#   {'name': 'Central Mediterranean route'},
#   {'name': 'Central European Route'},
#   {'name': 'Apulia and Calabria Route'},
#   {'name': 'Western African Route'},
#   {'name': 'Eastern Borders Route'},
#   {'name': 'Circular Route from Greece and Albania'},
#   {'name': 'Aegean'},
#   {'name': 'Spain'},
#   {'name': 'Libya'},
#   {'name': 'Turkey'},
#   {'name': 'Bulgaria'},
#   {'name': 'Egypt'},
#   {'name': 'Serbia'},
#   {'name': 'Germany'},
#   {'name': 'Hungary'},
#   {'name': 'Greece'},
#   {'name': 'Sardinia'},
#   {'name': 'Austria'},
#   {'name': 'Italy'},
#   {'name': 'Catania'},
#   {'name': 'Poland'},
#   {'name': 'Morocco'},
#   {'name': 'Lampedusa'},
#   {'name': 'Niger'},
#   {'name': 'Central Mediterranean'},
#   {'name': 'Africa'},
#   {'name': 'Sicily'},
#   {'name': 'Macedonia'},
#   {'name': 'Las Palmas, Spain'},
#   {'name': 'Malta'},
#   {'name': 'Algeria'},
#   {'name': 'Tunisia'},
#   {'name': 'Mediterranean Sea'},
#   {'name': 'Gibraltar'},
#   {'name': 'Guine'},
#   {'name': 'Chad'},
#   {'name': 'Linosa'},
#   {'name': 'Syria'},
#   {'name': 'Crete'},
#   {'name': 'Pantelleria'},
#   {'name': 'Balearic Islands'},
#   {'name': 'Senegal'},
#   {'name': 'Mauritania'},
#   {'name': 'France'},
#   {'name': 'Canary Islands'},
#   {'name': 'Dakar'},
#   {'name': 'Albania'},
#   {'name': 'Edko'},
#   {'name': 'Gambia'},
#   {'name': 'Lithuania'},
#   {'name': 'Barbados'},
#   {'name': 'Cyprus'},
#   {'name': 'Slovakia'},
#   {'name': 'Ukraine'},
#   {'name': 'Portugal'},
#   {'name': 'Zelid'},
#   {'name': 'Cameroon'},
#   {'name': 'Slovenia'},
#   {'name': 'Croatia'},
#   {'name': 'Romania'},
#   {'name': 'Southern Adriatic'},
#   {'name': 'Bojador'},
#   {'name': '2015'},
#   {'name': '2014'},
#   {'name': '2013'},
#   {'name': '2012'},
#   {'name': '2011'},
#   {'name': '2010'},
#   {'name': '2009'},
#   {'name': '2008'},
#   {'name': '2007'},
#   {'name': '2006'},
#   {'name': '2005'},
#   {'name': '2004'},
#   {'name': '2003'},
#   {'name': '2002'},
#   {'name': '2001'},
#   {'name': '2000'},
#   {'name': 'unknown - supposedly exhaustion related death'},
#   {'name': 'drowning or exhaustion related death'},
#   {'name': 'authorities related death'},
#   {'name': 'violent accidental death (transport, blown in minefield, etc)'},
#   {'name': 'malicious intent related death / manslaughter'},
#   {'name': 'suicide'},
#   {'name': 'other'}]}

# %% [markdown]
# ### Add percentage column for InternationalMigrantStocks_x/InternationalMigrantStocks_y for selected age group of selected gender, destination and year

# %%
df = pd.read_csv("data/International_and_totalStock_GenderAge.csv")

# %%
df['Gender'] = [i.replace('bothsexes ', 'bothsexes') if i=='bothsexes ' else i for i in df['Gender']]
df['Gender'] = [i.replace('female ', 'female') if i=='female ' else i for i in df['Gender']]
df['Gender'] = [i.replace('male ', 'male') if i=='male ' else i for i in df['Gender']]

# %%
df1 = df.groupby(['Year','Destination', 'Gender', 'AgeGroup'])['InternationalMigrantStocks'].sum().reset_index()

# %%
df2= df.groupby(['Year','Destination', 'Gender', 'AgeGroup'])['InternationalMigrantStocks'].sum().reset_index()\
.groupby(['Year','Destination', 'Gender'])['InternationalMigrantStocks'].sum().reset_index()

# %%
merged = pd.merge(df1, df2, how='left', on=['Year','Destination', 'Gender'])
# percentage of InternationalMigrantStocks_x/InternationalMigrantStocks_y for selected age group of selected gender, destination and year 
merged['ratio'] = merged['InternationalMigrantStocks_x']/merged['InternationalMigrantStocks_y']

# %%
merged = merged.rename({'InternationalMigrantStocks_y': 'Total_Y_D_G'}, axis=1)

# %%
# format_dict = { 'ratio': '{:.2%}'}
# merged.style.format(format_dict)

# %%
merged.head()
# Out:
#    Year  Destination     Gender AgeGroup  InternationalMigrantStocks_x  \
# 0  1990  Afghanistan  bothsexes      0-4                          3693
# 1  1990  Afghanistan  bothsexes    10-14                          4505
# 2  1990  Afghanistan  bothsexes    15-19                          5370
# 3  1990  Afghanistan  bothsexes    20-24                          6490
# 4  1990  Afghanistan  bothsexes    25-29                          7154
#
#    Total_Y_D_G     ratio
# 0        57686  0.064019
# 1        57686  0.078095
# 2        57686  0.093090
# 3        57686  0.112506
# 4        57686  0.124016

# %%
final = pd.merge(df, merged, how='left', on=['Year','Destination', 'Gender', 'AgeGroup'])

# %%
final = final.drop('InternationalMigrantStocks_x', axis=1)

# %%
final.to_csv("data/International_and_totalStock_GenderAge.csv", index=False)

# %% [markdown]
# ### Zero Migration Flow Creator

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # set seaborn default parameters for plots
# may have to pip install it: 
# pip install pycountry
import pycountry
import os
data_folder = 'data'
figures_folder = 'figures'
gender_dict = {'b': 'both', 'f': 'female', 'm': 'male'}

import warnings
warnings.filterwarnings("ignore")

# %%
def get_country_name(country_code, alpha=True):
    if alpha:
        return pycountry.countries.get(alpha_3=country_code).name
    else:
        return pycountry.countries.get(numeric=country_code).name

# %% [markdown]
# ## Data preparation

# %% [markdown]
# See section below for the explanations of the particular choices of `demo` and `stock`.

# %%
file_path = os.sep.join([data_folder, 'migflows_allcountries_gender_separated_1990_2015.csv'])
df = pd.read_csv(file_path)

# set whether you want to keep flows equal to zero in the dataset
remove_zero_flows_bool = True

print(f'Number of rows in original dataset: {df.shape[0]}.')

# select only time intervals of 5 years from 1990 to 2015 
df = df[(df.interval == 5) & (df.year0 >= 1990)]
print(f'Number of rows after filtering time interval: {df.shape[0]}.')

# select only the world population estimates of year 2015 
df = df[df.demo == 'wpp2015']
print(f'Number of rows after selecting only wpp2015 demographics: {df.shape[0]}.')

# select only the migrant stocks of year 2015 
df = df[df.stock == 'un15']
print(f'Number of rows after selecting only un2015 migrant stocks: {df.shape[0]}.')

# remove irrelevant and redundant columns
df.drop(columns=['stock', 'demo', 'interval'], inplace=True)

# request user to choose whether to keep the rows with 0 flow (this avoids forgetting about this option)
remove_zero_flows_str = input("Do you want to remove the rows with 0 flow? Answer by 'True' or 'False'.")
if remove_zero_flows_str.lower() == 'true':
    remove_zero_flows_bool = True
else:
    remove_zero_flows_bool = False
    
# remove rows with flow equal to 0
if remove_zero_flows_bool:
    df = df[df.flow > 0]
    print(f'Number of rows after removing rows with flow equal to 0: {df.shape[0]}.')

# get all countries in dataset
countries = set(df.orig.unique()).union(df.dest.unique())
print(f'There are {len(countries)} countries in MigrFlowSex dataset.')

iso_countries = {country.alpha_3 for country in pycountry.countries}
not_iso_countries = countries - iso_countries
print(f'There are {len(not_iso_countries)} not-ISO countries.')

# remove not-ISO countries
print(f"Let's remove them.")
df = df[~(df['orig'].isin(not_iso_countries) | df['dest'].isin(not_iso_countries))]
print(f'Number of rows after removing non-ISO countries {df.shape[0]}.')

countries_clean = set(df.orig.unique()).union(df.dest.unique())
assert len(countries_clean) == (len(countries) - len(not_iso_countries))
print(f'There are {len(countries_clean)} countries after removal.')
# Out:
# Number of rows in original dataset: 10321454.
# Number of rows after filtering time interval: 4901986.
# Number of rows after selecting only wpp2015 demographics: 1757100.
# Number of rows after selecting only un2015 migrant stocks: 590448.
# Do you want to remove the rows with 0 flow? Answer by 'True' or 'False'.True
# Number of rows after removing rows with flow equal to 0: 166052.
# There are 202 countries in MigrFlowSex dataset.
# There are 3 not-ISO countries.
# Let's remove them.
# Number of rows after removing non-ISO countries 162889.
# There are 199 countries after removal.

# %% [markdown]
# ### correct the both gender values based on female and male flow numbers

# %%
df_new = pd.pivot_table(df, values = 'flow', 
                        index=['year0', 'orig','dest', 'orig_code','dest_code'], columns = 'sex').reset_index()
# fill nan values with 0
df_new = df_new.fillna(0, axis=1)

# correct the type of the flow numbers
if df_new.columns.str.contains("b").any()==True:
            df_new['b'] = df_new['b'].astype(int)
        
if df_new.columns.str.contains("f").any()==True:
            df_new['f'] = df_new['f'].astype(int)
        
if df_new.columns.str.contains("m").any()==True:
            df_new['m'] = df_new['m'].astype(int)
        
# drop column 'b' to calculate new one from 'f' and 'm' values
df_new = df_new.drop(['b'], axis=1)
df_new['b'] = df_new['f'] + df_new['m']

# convert the data frame format again
df_new = pd.melt(df_new, id_vars=['year0', 'orig', 'dest', 'orig_code', 'dest_code'], var_name='sex', value_name='flow')
df_new = df_new[['sex', 'year0', 'orig', 'dest', 'orig_code', 'dest_code', 'flow']]

df_new.head()
# Out:
#   sex  year0 orig dest  orig_code  dest_code  flow
# 0   f   1990  ABW  CAN        533        124     0
# 1   f   1990  ABW  DEU        533        276     0
# 2   f   1990  ABW  FRA        533        250     0
# 3   f   1990  ABW  GBR        533        826     0
# 4   f   1990  ABW  NLD        533        528     0

# %%
# request user to choose whether to keep the rows with 0 flow (this avoids forgetting about this option)
remove_zero_flows_str = input("Do you want to remove the rows with 0 flow? Answer by 'True' or 'False'.")
if remove_zero_flows_str.lower() == 'true':
    remove_zero_flows_bool = True
else:
    remove_zero_flows_bool = False
    
# remove rows with flow equal to 0
if remove_zero_flows_bool:
    df_new = df_new[df_new.flow > 0]
    print(f'Number of rows after removing rows with flow equal to 0: {df_new.shape[0]}.')
# Out:
# Do you want to remove the rows with 0 flow? Answer by 'True' or 'False'.True
# Number of rows after removing rows with flow equal to 0: 167492.

# %%
# write to file
filename = f'migflows_gender_separated_1990_2015_filtered{"_without0flows" if remove_zero_flows_bool else ""}.csv'
df_new.to_csv(os.sep.join([data_folder, filename]), index=False)
